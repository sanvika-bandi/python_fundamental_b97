# %%
#introduction to f strings
firstname="raju yadav"
lastname="cheruvu"
fullname=f"{firstname} {lastname}"
print(fullname)
# Out:
# raju yadav cheruvu

# %%
firstname1="pranitha"
lastname1="goud"
fullname=f"{firstname1} {lastname1}"
print(fullname.title())
# Out:
# Pranitha Goud

# %%
message=f"good girl keep it up ,{fullname.title()}"
print(message)
# Out:
# good girl keep it up ,Pranitha Goud

# %%
#Adding white spaces
print("flowers:roselillylotustulip")
# Out:
# flowers:roselillylotustulip

# %%
print("flowers:\nrose\nlilly\nlotus\ntulip")#\n--->new line delimiter
# Out:
# flowers:
# rose
# lilly
# lotus
# tulip

# %%
print("groups:\n\tCSE\n\tECE\n\tMI\n\tAERONAUTICAL")
# Out:
# groups:
# 	CSE
# 	ECE
# 	MI
# 	AERONAUTICAL

# %%
#removing white spaces
a=" python"
print(a)
# Out:
#  python

# %%
print(a.lstrip())
# Out:
# python

# %%
b="java "
print(b)
# Out:
# java

# %%
print(b.rstrip())
# Out:
# java

# %%
c=" conclusion "
print(c)
# Out:
#  conclusion

# %%
print(c.strip())
# Out:
# conclusion
