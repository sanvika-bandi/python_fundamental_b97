# %%
#organising data in list:
cars=['kia','audi','bmw','benz','hyundai','wolksvogon','suzuki']
print(cars)
# Out:
# ['kia', 'audi', 'bmw', 'benz', 'hyundai', 'wolksvogon', 'suzuki']

# %%
print(sorted(cars))
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'suzuki', 'wolksvogon']

# %%
len(cars)
# Out:
# 7

# %%
cars.sort
print(cars)
# Out:
# ['kia', 'audi', 'bmw', 'benz', 'hyundai', 'wolksvogon', 'suzuki']

# %%
cars.reverse()
print(cars)
# Out:
# ['suzuki', 'wolksvogon', 'hyundai', 'benz', 'bmw', 'audi', 'kia']

# %%
chocolates=['dairymilk','fivestar','kitkat','chocobar','munch','peark']
print(chocolates)
# Out:
# ['dairymilk', 'fivestar', 'kitkat', 'chocobar', 'munch', 'peark']

# %%
len(chocolates)
# Out:
# 6

# %%
print(sorted(chocolates))
# Out:
# ['chocobar', 'dairymilk', 'fivestar', 'kitkat', 'munch', 'peark']

# %%
chocolates.sort()
print(chocolates)
# Out:
# ['chocobar', 'dairymilk', 'fivestar', 'kitkat', 'munch', 'peark']

# %%
chocolates.reverse()
print(chocolates)
# Out:
# ['peark', 'munch', 'kitkat', 'fivestar', 'dairymilk', 'chocobar']

# %%
fruits=['apple','jackfruit','mango','grapes','kiwi','pineapple','guava']
print(fruits)
# Out:
# ['apple', 'jackfruit', 'mango', 'grapes', 'kiwi', 'pineapple', 'guava']

# %%
len(fruits)
# Out:
# 7

# %%
print(sorted(fruits))
# Out:
# ['apple', 'grapes', 'guava', 'jackfruit', 'kiwi', 'mango', 'pineapple']

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'grapes', 'guava', 'jackfruit', 'kiwi', 'mango', 'pineapple']

# %%
fruits.reverse()
print(fruits)
# Out:
# ['pineapple', 'mango', 'kiwi', 'jackfruit', 'guava', 'grapes', 'apple']

# %%
#introduction to slicing
courses=['Ba','Bba','Mpcs','Msds','honours','Bcom','mdscs','bzcs']
print(courses)
# Out:
# ['Ba', 'Bba', 'Mpcs', 'Msds', 'honours', 'Bcom', 'mdscs', 'bzcs']

# %%
print(courses[0:9])
# Out:
# ['Ba', 'Bba', 'Mpcs', 'Msds', 'honours', 'Bcom', 'mdscs', 'bzcs']

# %%
print(courses[0:6])
# Out:
# ['Ba', 'Bba', 'Mpcs', 'Msds', 'honours', 'Bcom']

# %%
print(courses[0:9:3])
# Out:
# ['Ba', 'Msds', 'mdscs']

# %%
print(courses[0:9:2])
# Out:
# ['Ba', 'Mpcs', 'honours', 'mdscs']

# %%
print(fruits[0:9])
# Out:
# ['pineapple', 'mango', 'kiwi', 'jackfruit', 'guava', 'grapes', 'apple']

# %%
#introduction to tuple datatype:
area_size=(23,55)
print(area_size)
# Out:
# (23, 55)

# %%
a=(1
