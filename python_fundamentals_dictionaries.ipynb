# %%
alien={'color':'green','points':5}
print(alien)
type(alien)
# Out:
# {'color': 'green', 'points': 5}
# dict

# %%
alien['start_position']='level1'
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
alien['color']#key will be acting as indexing point
# Out:
# 'green'

# %%
#new user account
user_account={'username':'coder','username':'code','password':'12345'}
print(user_account)
# Out:
# {'username': 'code', 'password': '12345'}

# %%
del user_account['password']
print(user_account)
# Out:
# {'username': 'code'}

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
alien['5']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 alien['5']
#
# KeyError: '5'

# %%
for k,v in alien.items():
    print(k)
    print(v)
# Out:
# color
# green
# points
# 5
# start_position
# level1

# %%
for k,v in alien.items():
    print(f"keys:{k}")
    print(f"values:{v}\n")
# Out:
# keys:color
# values:green
#
# keys:points
# values:5
#
# keys:start_position
# values:level1
