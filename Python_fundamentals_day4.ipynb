# %%
# Out:
#   Cell In[3], line 4
#     print(num\t,num2)
#               ^
# SyntaxError: unexpected character after line continuation character

# %%
#introduction to numbers
num=12
print(num)
type(num)
# Out:
# 12
# int

# %%
x=0.8
print(x)
type(x)
# Out:
# 0.8
# float

# %%
#introduction to list
a=['1','2','3']
print(a)
type(a)
# Out:
# ['1', '2', '3']
# list

# %%
print(a[1])#indexing of list
# Out:
# 2

# %%
y=['math','phy','bio']
print(y[0].title())
# Out:
# Math

# %%
y.append('c')
print(y)
# Out:
# ['math', 'phy', 'bio', 'c']

# %%
y.insert(1,'python')
print(y)
# Out:
# ['math', 'python', 'phy', 'bio', 'c']

# %%
#modify phy name to java
y[2]='java'
print(y)
# Out:
# ['math', 'python', 'java', 'bio', 'c']

# %%
z=y.pop()
print(y)
print(z)
# Out:
# ['math', 'python', 'java', 'bio']
# c

# %%
y.pop(3)
print(y)
# Out:
# ['math', 'python', 'java']

# %%
del y[0]
print(y)
# Out:
# ['python', 'java']
