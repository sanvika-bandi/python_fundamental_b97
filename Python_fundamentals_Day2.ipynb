# %%
#variables
a=2
b=4
c=a+b
print(c)
# Out:
# 6

# %%
#no name spaces while declaring variables
first name="sanvi"
print(first name)
# Out:
#   Cell In[2], line 2
#     first name="sanvi"
#           ^
# SyntaxError: invalid syntax

# %%
first_name="sanvi"
print(first_name)
# Out:
# sanvi

# %%
#variable should not start with numbers
1name="raj"
print(1name)
# Out:
#   Cell In[4], line 2
#     1name="raj"
#     ^
# SyntaxError: invalid decimal literal

# %%
#variable should not contain any special characters
name@="lucy"
print(name@)
# Out:
#   Cell In[5], line 3
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
name2="raj"
print(name2)
# Out:
# raj

# %%
#Introduction to string and its methods:
name="raj yadav"
print(name)
type(name)
# Out:
# raj yadav
# str

# %%
print(name.title())
# Out:
# Raj Yadav

# %%
print(name.upper())
print(name.lower()
